# %% [markdown]
# <a href="https://colab.research.google.com/github/Alanalfachrizzy/UTS_Ganjil_A_2006193_Fachrry-Al-Fachrizzy-Risyandi/blob/main/SoalUTSGanjilA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

from google.colab.patches import cv2_imshow
from skimage import io
from PIL import Image

# %%
#link image
url ="https://lh5.googleusercontent.com/sk7eNX9SeEnY-5f5_nI_qEqcRd8TyRKP7yQ3X2lLad8vfy08jTGNCg2juTBbGEUFMlY=w2400"

image = io.imread(url)
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
final_frame = cv.hconcat((image, image_2))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x480 at 0x7F38DAF25FD0>

# %%
print(image.size)
print(image.shape)
print(image.dtype)
# Out:
# 921600
# (480, 640, 3)
# uint8

# %%
import numpy as np
a = np.array([[1,2,2,2,10],[10,20,30,40,50]])
print(a)
print(a.ravel())
print(a.flatten())
plt.hist(a.ravel(),bins = 50, range = [0,50])
plt.show()
# Out:
# [[ 1  2  2  2 10]
#  [10 20 30 40 50]]
# [ 1  2  2  2 10 10 20 30 40 50]
# [ 1  2  2  2 10 10 20 30 40 50]

# %%
plt.hist(image.ravel(), bins = 256, range = [0,256])
plt.show()

# %%
color = ('b','g','r')
for i,col in enumerate(color):
  histogram = cv.calcHist([image], [i], None, [256], [0,256])
  plt.plot(histogram, color = col)
  plt.xlim([0,256])
plt.show()

# %%
color = ('b','g','r')
for i,col in enumerate(color):
  histogr = cv.calcHist([image], [i], None, [4], [0,256])
  plt.plot(histogr, color = col)
  plt.xlim([0,4])
plt.show()

# %%
color = ('b','g','r')
for i,col in enumerate(color):
  histogr = cv.calcHist([image], [i], None, [8], [0,256])
  plt.plot(histogr, color = col)
  plt.show()

# %%
color = ('b','g','r')
for i,col in enumerate(color):
  histogr = cv.calcHist([image], [i], None, [16], [0,256])
  plt.plot(histogr, color = col)
plt.show()

# %%
color = ('b','g','r')
for i,col in enumerate(color):
  histogr = cv.calcHist([image], [i], None, [32], [0,256])
  plt.plot(histogr, color = col)
plt.show()

# %%
b,g,r = cv.split(image)
cv2_imshow(b)
# Out:
# <PIL.Image.Image image mode=L size=640x480 at 0x7F38DB8E94D0>

# %%
image = io.imread(url)

#blue channel
bluech = image[:,:,0]
cv2_imshow(bluech)
# Out:
# <PIL.Image.Image image mode=L size=640x480 at 0x7F38DF681BD0>

# %%
plt.hist(bluech.ravel(), 16, [0, 256], color='blue')
plt.xlabel('Bins 16')
plt.ylabel('Num of Pixel')
plt.show()

# %%
plt.hist(bluech.ravel(), 8, [0, 256], color='blue')
plt.xlabel('Bins 32')
plt.ylabel('Num of Pixel')
plt.show()

# %%
plt.hist(bluech.ravel(), 32, [0, 256], color='blue')
plt.xlabel('Bins 8')
plt.ylabel('Num of Pixel')
plt.show()

# %%
plt.hist(bluech.ravel(), 256, [0, 256], color='blue')
plt.xlabel('Bins 256')
plt.ylabel('Num of Pixel')
plt.show()

# %%
plt.hist(bluech.ravel(), 4, [0, 256], color='blue')
plt.xlabel('Bins 4')
plt.ylabel('Num of Pixel')
plt.show()

# %%
#green channel
greench = image[:,:,1]
cv2_imshow(greench)
# Out:
# <PIL.Image.Image image mode=L size=640x480 at 0x7F38DB6DA450>

# %%
plt.hist(bluech.ravel(), 8, [0, 256], color='green')
plt.xlabel('Bins 32')
plt.ylabel('Num of Pixel')
plt.show()

# %%
plt.hist(bluech.ravel(), 4, [0, 256], color='green')
plt.xlabel('Bins 4')
plt.ylabel('Num of Pixel')
plt.show()

# %%
plt.hist(bluech.ravel(), 16, [0, 256], color='green')
plt.xlabel('Bins 16')
plt.ylabel('Num of Pixel')
plt.show()

# %%
plt.hist(bluech.ravel(), 32, [0, 256], color='green')
plt.xlabel('Bins 8')
plt.ylabel('Num of Pixel')
plt.show()

# %%
plt.hist(bluech.ravel(), 256, [0, 256], color='green')
plt.xlabel('Bins 256')
plt.ylabel('Num of Pixel')
plt.show()

# %%
#red channel

redch = image[:,:,2]
cv2_imshow(redch)
# Out:
# <PIL.Image.Image image mode=L size=640x480 at 0x7F38D80DF850>

# %%
plt.hist(redch.ravel(), 256, [0, 256], color='red')
plt.xlabel('Bins 256')
plt.ylabel('Num of Pixel')
plt.show()

# %%
plt.hist(redch.ravel(), 32, [0, 256], color='red')
plt.xlabel('Bins 8')
plt.ylabel('Num of Pixel')
plt.show()

# %%
plt.hist(redch.ravel(), 16, [0, 256], color='red')
plt.xlabel('Bins 16')
plt.ylabel('Num of Pixel')
# Out:
# Text(0, 0.5, 'Num of Pixel')

# %%
plt.hist(redch.ravel(), 8, [0, 256], color='red')
plt.xlabel('Bins 32')
plt.ylabel('Num of Pixel')
# Out:
# Text(0, 0.5, 'Num of Pixel')

# %%
plt.hist(redch.ravel(), 4, [0, 256], color='red')
plt.xlabel('Bins 4')
plt.ylabel('Num of Pixel')
# Out:
# Text(0, 0.5, 'Num of Pixel')

# %%
gray_image = cv.cvtColor(image, cv.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=640x480 at 0x7F38D7DEFC10>

# %%
plt.hist(gray_image.ravel(), bins = 256, range = [0,256])
plt.show()


print(gray_image.size)
print(gray_image.shape)
print(gray_image.dtype)
# Out:
# 307200
# (480, 640)
# uint8

# %%
plt.hist(gray_image.ravel(), bins = 4, range = [0,256])
plt.show()


print(gray_image.size)
print(gray_image.shape)
print(gray_image.dtype)
# Out:
# 307200
# (480, 640)
# uint8

# %%
invert_gray = 255 - gray_image
cv2_imshow(invert_gray)
# Out:
# <PIL.Image.Image image mode=L size=640x480 at 0x7F38DF67C390>

# %%
plt.hist(invert_gray.ravel(), bins = 256, range = [0,256])
plt.show()

# %%
bright_image = (100.0/255)*gray_image + 100
cv2_imshow(bright_image)
# Out:
# <PIL.Image.Image image mode=L size=640x480 at 0x7F38DB5D8110>

# %%
plt.hist(bright_image.ravel(), bins = 256, range = [0,256])
plt.show()

# %%
darken_image = 255.0*(gray_image/255.0)**2
cv2_imshow(darken_image)
# Out:
# <PIL.Image.Image image mode=L size=640x480 at 0x7F38DB16F690>

# %%
plt.hist(darken_image.ravel(), bins = 256, range = [0,256])
plt.show()
